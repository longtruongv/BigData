# %%
from pyspark import SparkContext, SparkConf
from pyspark.sql import SparkSession

# %%
try:
    sc.stop()
except:
    print("SparkContext has not been initiated")
# Out:
# SparkContext has not bseen initiated

# %%
conf = SparkConf() \
    .set("spark.jars.packages", "org.mongodb.spark:mongo-spark-connector_2.12:3.0.1,org.postgresql:postgresql:42.5.0") \

sc = SparkContext(conf=conf)

spark = SparkSession.builder \
    .master("spark://spark-master:7077") \
    .appName("myApp") \
    .getOrCreate()

spark
# Out:
#             <div>
#                 <p><b>SparkSession - in-memory</b></p>
#
#         <div>
#             <p><b>SparkContext</b></p>
#
#             <p><a href="http://78b1fd82022d:4040">Spark UI</a></p>
#
#             <dl>
#               <dt>Version</dt>
#                 <dd><code>v3.3.1</code></dd>
#               <dt>Master</dt>
#                 <dd><code>local[*]</code></dd>
#               <dt>AppName</dt>
#                 <dd><code>pyspark-shell</code></dd>
#             </dl>
#         </div>
#
#             </div>

# %%
player_df = spark.read \
    .format("com.mongodb.spark.sql.DefaultSource") \
    .option('uri', "mongodb://mongodb:27017/football_data.player") \
    .load()
    
player_df.printSchema()
# Out:
# root
#  |-- _id: string (nullable = true)
#  |-- info: struct (nullable = true)
#  |    |-- ShortName: string (nullable = true)
#  |    |-- FullName: void (nullable = true)
#  |    |-- Position: void (nullable = true)
#  |    |-- Height: void (nullable = true)
#  |    |-- Weight: void (nullable = true)
#  |    |-- Footed: void (nullable = true)
#  |    |-- DOB: string (nullable = true)
#  |    |-- Nationality: string (nullable = true)
#  |    |-- Club: string (nullable = true)
#  |-- stats: struct (nullable = true)
#  |    |-- adv_goalkeeping: array (nullable = true)
#  |    |    |-- element: struct (containsNull = true)
#  |    |    |    |-- Season: string (nullable = true)
#  |    |    |    |-- Age: string (nullable = true)
#  |    |    |    |-- Squad: array (nullable = true)
#  |    |    |    |    |-- element: string (containsNull = true)
#  |    |    |    |-- Country: array (nullable = true)
#  |    |    |    |    |-- element: string (containsNull = true)
#  |    |    |    |-- Comp: array (nullable = true)
#  |    |    |    |    |-- element: string (containsNull = true)
#  |    |    |    |-- LgRank: string (nullable = true)
#  |    |    |    |-- 90s: string (nullable = true)
#  |    |    |    |-- GA: string (nullable = true)
#  |    |    |    |-- PKA: string (nullable = true)
#  |    |    |    |-- FK: string (nullable = true)
#  |    |    |    |-- CK: string (nullable = true)
#  |    |    |    |-- OG: string (nullable = true)
#  |    |    |    |-- PSxG: string (nullable = true)
#  |    |    |    |-- PSxG/SoT: string (nullable = true)
#  |    |    |    |-- PSxG+/-: string (nullable = true)
#  |    |    |    |-- /90: string (nullable = true)
#  |    |    |    |-- Cmp: string (nullable = true)
#  |    |    |    |-- Att: string (nullable = true)
#  |    |    |    |-- Cmp%: string (nullable = true)
#  |    |    |    |-- Thr: string (nullable = true)
#  |    |    |    |-- Launch%: string (nullable = true)
#  |    |    |    |-- AvgLen: string (nullable = true)
#  |    |    |    |-- Opp: string (nullable = true)
#  |    |    |    |-- Stp: string (nullable = true)
#  |    |    |    |-- Stp%: string (nullable = true)
#  |    |    |    |-- #OPA: string (nullable = true)
#  |    |    |    |-- #OPA/90: string (nullable = true)
#  |    |    |    |-- AvgDist: string (nullable = true)
#  |    |    |    |-- Matches: array (nullable = true)
#  |    |    |    |    |-- element: string (containsNull = true)
#  |    |-- defensive: array (nullable = true)
#  |    |    |-- element: struct (containsNull = true)
#  |    |    |    |-- Season: string (nullable = true)
#  |    |    |    |-- Age: string (nullable = true)
#  |    |    |    |-- Squad: array (nullable = true)
#  |    |    |    |    |-- element: string (containsNull = true)
#  |    |    |    |-- Country: array (nullable = true)
#  |    |    |    |    |-- element: string (containsNull = true)
#  |    |    |    |-- Comp: array (nullable = true)
#  |    |    |    |    |-- element: string (containsNull = true)
#  |    |    |    |-- LgRank: string (nullable = true)
#  |    |    |    |-- 90s: string (nullable = true)
#  |    |    |    |-- Tkl: string (nullable = true)
#  |    |    |    |-- TklW: string (nullable = true)
#  |    |    |    |-- Def 3rd: string (nullable = true)
#  |    |    |    |-- Mid 3rd: string (nullable = true)
#  |    |    |    |-- Att 3rd: string (nullable = true)
#  |    |    |    |-- Att: string (nullable = true)
#  |    |    |    |-- Tkl%: string (nullable = true)
#  |    |    |    |-- Past: string (nullable = true)
#  |    |    |    |-- Blocks: string (nullable = true)
#  |    |    |    |-- Sh: string (nullable = true)
#  |    |    |    |-- Pass: string (nullable = true)
#  |    |    |    |-- Int: string (nullable = true)
#  |    |    |    |-- Tkl+Int: string (nullable = true)
#  |    |    |    |-- Clr: string (nullable = true)
#  |    |    |    |-- Err: string (nullable = true)
#  |    |    |    |-- Matches: array (nullable = true)
#  |    |    |    |    |-- element: string (containsNull = true)
#  |    |-- goal_shot_creation: array (nullable = true)
#  |    |    |-- element: struct (containsNull = true)
#  |    |    |    |-- Season: string (nullable = true)
#  |    |    |    |-- Age: string (nullable = true)
#  |    |    |    |-- Squad: array (nullable = true)
#  |    |    |    |    |-- element: string (containsNull = true)
#  |    |    |    |-- Country: array (nullable = true)
#  |    |    |    |    |-- element: string (containsNull = true)
#  |    |    |    |-- Comp: array (nullable = true)
#  |    |    |    |    |-- element: string (containsNull = true)
#  |    |    |    |-- LgRank: string (nullable = true)
#  |    |    |    |-- 90s: string (nullable = true)
#  |    |    |    |-- SCA: string (nullable = true)
#  |    |    |    |-- SCA90: string (nullable = true)
#  |    |    |    |-- PassLive: string (nullable = true)
#  |    |    |    |-- PassDead: string (nullable = true)
#  |    |    |    |-- Drib: string (nullable = true)
#  |    |    |    |-- Sh: string (nullable = true)
#  |    |    |    |-- Fld: string (nullable = true)
#  |    |    |    |-- Def: string (nullable = true)
#  |    |    |    |-- GCA: string (nullable = true)
#  |    |    |    |-- GCA90: string (nullable = true)
#  |    |    |    |-- Matches: array (nullable = true)
#  |    |    |    |    |-- element: string (containsNull = true)
#  |    |-- goalkeeping: array (nullable = true)
#  |    |    |-- element: struct (containsNull = true)
#  |    |    |    |-- Season: string (nullable = true)
#  |    |    |    |-- Age: string (nullable = true)
#  |    |    |    |-- Squad: array (nullable = true)
#  |    |    |    |    |-- element: string (containsNull = true)
#  |    |    |    |-- Country: array (nullable = true)
#  |    |    |    |    |-- element: string (containsNull = true)
#  |    |    |    |-- Comp: array (nullable = true)
#  |    |    |    |    |-- element: string (containsNull = true)
#  |    |    |    |-- LgRank: string (nullable = true)
#  |    |    |    |-- MP: string (nullable = true)
#  |    |    |    |-- Starts: string (nullable = true)
#  |    |    |    |-- Min: string (nullable = true)
#  |    |    |    |-- 90s: string (nullable = true)
#  |    |    |    |-- GA: string (nullable = true)
#  |    |    |    |-- GA90: string (nullable = true)
#  |    |    |    |-- SoTA: string (nullable = true)
#  |    |    |    |-- Saves: string (nullable = true)
#  |    |    |    |-- Save%: string (nullable = true)
#  |    |    |    |-- W: string (nullable = true)
#  |    |    |    |-- D: string (nullable = true)
#  |    |    |    |-- L: string (nullable = true)
#  |    |    |    |-- CS: string (nullable = true)
#  |    |    |    |-- CS%: string (nullable = true)
#  |    |    |    |-- PKatt: string (nullable = true)
#  |    |    |    |-- PKA: string (nullable = true)
#  |    |    |    |-- PKsv: string (nullable = true)
#  |    |    |    |-- PKm: string (nullable = true)
#  |    |    |    |-- Matches: array (nullable = true)
#  |    |    |    |    |-- element: string (containsNull = true)
#  |    |-- miscellaneous: array (nullable = true)
#  |    |    |-- element: struct (containsNull = true)
#  |    |    |    |-- 2CrdY: string (nullable = true)
#  |    |    |    |-- 90s: string (nullable = true)
#  |    |    |    |-- Age: string (nullable = true)
#  |    |    |    |-- Comp: array (nullable = true)
#  |    |    |    |    |-- element: string (containsNull = true)
#  |    |    |    |-- Country: array (nullable = true)
#  |    |    |    |    |-- element: string (containsNull = true)
#  |    |    |    |-- CrdR: string (nullable = true)
#  |    |    |    |-- CrdY: string (nullable = true)
#  |    |    |    |-- Crs: string (nullable = true)
#  |    |    |    |-- Fld: string (nullable = true)
#  |    |    |    |-- Fls: string (nullable = true)
#  |    |    |    |-- Int: string (nullable = true)
#  |    |    |    |-- LgRank: string (nullable = true)
#  |    |    |    |-- Lost: string (nullable = true)
#  |    |    |    |-- Matches: array (nullable = true)
#  |    |    |    |    |-- element: string (containsNull = true)
#  |    |    |    |-- OG: string (nullable = true)
#  |    |    |    |-- Off: string (nullable = true)
#  |    |    |    |-- PKcon: string (nullable = true)
#  |    |    |    |-- PKwon: string (nullable = true)
#  |    |    |    |-- Recov: string (nullable = true)
#  |    |    |    |-- Season: string (nullable = true)
#  |    |    |    |-- Squad: array (nullable = true)
#  |    |    |    |    |-- element: string (containsNull = true)
#  |    |    |    |-- TklW: string (nullable = true)
#  |    |    |    |-- Won: string (nullable = true)
#  |    |    |    |-- Won%: string (nullable = true)
#  |    |-- pass_type: array (nullable = true)
#  |    |    |-- element: struct (containsNull = true)
#  |    |    |    |-- Season: string (nullable = true)
#  |    |    |    |-- Age: string (nullable = true)
#  |    |    |    |-- Squad: array (nullable = true)
#  |    |    |    |    |-- element: string (containsNull = true)
#  |    |    |    |-- Country: array (nullable = true)
#  |    |    |    |    |-- element: string (containsNull = true)
#  |    |    |    |-- Comp: array (nullable = true)
#  |    |    |    |    |-- element: string (containsNull = true)
#  |    |    |    |-- LgRank: string (nullable = true)
#  |    |    |    |-- 90s: string (nullable = true)
#  |    |    |    |-- Att: string (nullable = true)
#  |    |    |    |-- Live: string (nullable = true)
#  |    |    |    |-- Dead: string (nullable = true)
#  |    |    |    |-- FK: string (nullable = true)
#  |    |    |    |-- TB: string (nullable = true)
#  |    |    |    |-- Sw: string (nullable = true)
#  |    |    |    |-- Crs: string (nullable = true)
#  |    |    |    |-- TI: string (nullable = true)
#  |    |    |    |-- CK: string (nullable = true)
#  |    |    |    |-- In: string (nullable = true)
#  |    |    |    |-- Out: string (nullable = true)
#  |    |    |    |-- Str: string (nullable = true)
#  |    |    |    |-- Cmp: string (nullable = true)
#  |    |    |    |-- Off: string (nullable = true)
#  |    |    |    |-- Blocks: string (nullable = true)
#  |    |    |    |-- Matches: array (nullable = true)
#  |    |    |    |    |-- element: string (containsNull = true)
#  |    |-- passing: array (nullable = true)
#  |    |    |-- element: struct (containsNull = true)
#  |    |    |    |-- Season: string (nullable = true)
#  |    |    |    |-- Age: string (nullable = true)
#  |    |    |    |-- Squad: array (nullable = true)
#  |    |    |    |    |-- element: string (containsNull = true)
#  |    |    |    |-- Country: array (nullable = true)
#  |    |    |    |    |-- element: string (containsNull = true)
#  |    |    |    |-- Comp: array (nullable = true)
#  |    |    |    |    |-- element: string (containsNull = true)
#  |    |    |    |-- LgRank: string (nullable = true)
#  |    |    |    |-- 90s: string (nullable = true)
#  |    |    |    |-- Cmp: string (nullable = true)
#  |    |    |    |-- Att: string (nullable = true)
#  |    |    |    |-- Cmp%: string (nullable = true)
#  |    |    |    |-- TotDist: string (nullable = true)
#  |    |    |    |-- PrgDist: string (nullable = true)
#  |    |    |    |-- Ast: string (nullable = true)
#  |    |    |    |-- xAG: string (nullable = true)
#  |    |    |    |-- xA: string (nullable = true)
#  |    |    |    |-- A-xAG: string (nullable = true)
#  |    |    |    |-- KP: string (nullable = true)
#  |    |    |    |-- 1/3: string (nullable = true)
#  |    |    |    |-- PPA: string (nullable = true)
#  |    |    |    |-- CrsPA: string (nullable = true)
#  |    |    |    |-- Prog: string (nullable = true)
#  |    |    |    |-- Matches: array (nullable = true)
#  |    |    |    |    |-- element: string (containsNull = true)
#  |    |-- playing_time: array (nullable = true)
#  |    |    |-- element: struct (containsNull = true)
#  |    |    |    |-- +/-: string (nullable = true)
#  |    |    |    |-- +/-90: string (nullable = true)
#  |    |    |    |-- 90s: string (nullable = true)
#  |    |    |    |-- Age: string (nullable = true)
#  |    |    |    |-- Comp: array (nullable = true)
#  |    |    |    |    |-- element: string (containsNull = true)
#  |    |    |    |-- Compl: string (nullable = true)
#  |    |    |    |-- Country: array (nullable = true)
#  |    |    |    |    |-- element: string (containsNull = true)
#  |    |    |    |-- LgRank: string (nullable = true)
#  |    |    |    |-- MP: string (nullable = true)
#  |    |    |    |-- Matches: array (nullable = true)
#  |    |    |    |    |-- element: string (containsNull = true)
#  |    |    |    |-- Min: string (nullable = true)
#  |    |    |    |-- Min%: string (nullable = true)
#  |    |    |    |-- Mn/MP: string (nullable = true)
#  |    |    |    |-- Mn/Start: string (nullable = true)
#  |    |    |    |-- Mn/Sub: string (nullable = true)
#  |    |    |    |-- On-Off: string (nullable = true)
#  |    |    |    |-- PPM: string (nullable = true)
#  |    |    |    |-- Season: string (nullable = true)
#  |    |    |    |-- Squad: array (nullable = true)
#  |    |    |    |    |-- element: string (containsNull = true)
#  |    |    |    |-- Starts: string (nullable = true)
#  |    |    |    |-- Subs: string (nullable = true)
#  |    |    |    |-- onG: string (nullable = true)
#  |    |    |    |-- onGA: string (nullable = true)
#  |    |    |    |-- onxG: string (nullable = true)
#  |    |    |    |-- onxGA: string (nullable = true)
#  |    |    |    |-- unSub: string (nullable = true)
#  |    |    |    |-- xG+/-: string (nullable = true)
#  |    |    |    |-- xG+/-90: string (nullable = true)
#  |    |-- possession: array (nullable = true)
#  |    |    |-- element: struct (containsNull = true)
#  |    |    |    |-- Season: string (nullable = true)
#  |    |    |    |-- Age: string (nullable = true)
#  |    |    |    |-- Squad: array (nullable = true)
#  |    |    |    |    |-- element: string (containsNull = true)
#  |    |    |    |-- Country: array (nullable = true)
#  |    |    |    |    |-- element: string (containsNull = true)
#  |    |    |    |-- Comp: array (nullable = true)
#  |    |    |    |    |-- element: string (containsNull = true)
#  |    |    |    |-- LgRank: string (nullable = true)
#  |    |    |    |-- 90s: string (nullable = true)
#  |    |    |    |-- Touches: string (nullable = true)
#  |    |    |    |-- Def Pen: string (nullable = true)
#  |    |    |    |-- Def 3rd: string (nullable = true)
#  |    |    |    |-- Mid 3rd: string (nullable = true)
#  |    |    |    |-- Att 3rd: string (nullable = true)
#  |    |    |    |-- Att Pen: string (nullable = true)
#  |    |    |    |-- Live: string (nullable = true)
#  |    |    |    |-- Succ: string (nullable = true)
#  |    |    |    |-- Att: string (nullable = true)
#  |    |    |    |-- Succ%: string (nullable = true)
#  |    |    |    |-- Mis: string (nullable = true)
#  |    |    |    |-- Dis: string (nullable = true)
#  |    |    |    |-- Rec: string (nullable = true)
#  |    |    |    |-- Prog: string (nullable = true)
#  |    |    |    |-- Matches: array (nullable = true)
#  |    |    |    |    |-- element: string (containsNull = true)
#  |    |-- shooting: array (nullable = true)
#  |    |    |-- element: struct (containsNull = true)
#  |    |    |    |-- 90s: string (nullable = true)
#  |    |    |    |-- Age: string (nullable = true)
#  |    |    |    |-- Comp: array (nullable = true)
#  |    |    |    |    |-- element: string (containsNull = true)
#  |    |    |    |-- Country: array (nullable = true)
#  |    |    |    |    |-- element: string (containsNull = true)
#  |    |    |    |-- Dist: string (nullable = true)
#  |    |    |    |-- FK: string (nullable = true)
#  |    |    |    |-- G-xG: string (nullable = true)
#  |    |    |    |-- G/Sh: string (nullable = true)
#  |    |    |    |-- G/SoT: string (nullable = true)
#  |    |    |    |-- Gls: string (nullable = true)
#  |    |    |    |-- LgRank: string (nullable = true)
#  |    |    |    |-- Matches: array (nullable = true)
#  |    |    |    |    |-- element: string (containsNull = true)
#  |    |    |    |-- PK: string (nullable = true)
#  |    |    |    |-- PKatt: string (nullable = true)
#  |    |    |    |-- Season: string (nullable = true)
#  |    |    |    |-- Sh: string (nullable = true)
#  |    |    |    |-- Sh/90: string (nullable = true)
#  |    |    |    |-- SoT: string (nullable = true)
#  |    |    |    |-- SoT%: string (nullable = true)
#  |    |    |    |-- SoT/90: string (nullable = true)
#  |    |    |    |-- Squad: array (nullable = true)
#  |    |    |    |    |-- element: string (containsNull = true)
#  |    |    |    |-- np:G-xG: string (nullable = true)
#  |    |    |    |-- npxG: string (nullable = true)
#  |    |    |    |-- npxG/Sh: string (nullable = true)
#  |    |    |    |-- xG: string (nullable = true)
#  |    |-- std: array (nullable = true)
#  |    |    |-- element: struct (containsNull = true)
#  |    |    |    |-- 90s: string (nullable = true)
#  |    |    |    |-- Age: string (nullable = true)
#  |    |    |    |-- Ast: string (nullable = true)
#  |    |    |    |-- Comp: array (nullable = true)
#  |    |    |    |    |-- element: string (containsNull = true)
#  |    |    |    |-- Country: array (nullable = true)
#  |    |    |    |    |-- element: string (containsNull = true)
#  |    |    |    |-- CrdR: string (nullable = true)
#  |    |    |    |-- CrdY: string (nullable = true)
#  |    |    |    |-- G+A: string (nullable = true)
#  |    |    |    |-- G+A-PK: string (nullable = true)
#  |    |    |    |-- G-PK: string (nullable = true)
#  |    |    |    |-- Gls: string (nullable = true)
#  |    |    |    |-- LgRank: string (nullable = true)
#  |    |    |    |-- MP: string (nullable = true)
#  |    |    |    |-- Matches: array (nullable = true)
#  |    |    |    |    |-- element: string (containsNull = true)
#  |    |    |    |-- Min: string (nullable = true)
#  |    |    |    |-- PK: string (nullable = true)
#  |    |    |    |-- PKatt: string (nullable = true)
#  |    |    |    |-- Season: string (nullable = true)
#  |    |    |    |-- Squad: array (nullable = true)
#  |    |    |    |    |-- element: string (containsNull = true)
#  |    |    |    |-- Starts: string (nullable = true)
#  |    |    |    |-- npxG: string (nullable = true)
#  |    |    |    |-- npxG+xAG: string (nullable = true)
#  |    |    |    |-- xAG: string (nullable = true)
#  |    |    |    |-- xG: string (nullable = true)
#  |    |    |    |-- xG+xAG: string (nullable = true)
#  |-- type: string (nullable = true)

# %%
for row in
std = spark.createDataFrame(player_df['stats']['std'])
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[12], line 1
# ----> 1 std = spark.createDataFrame(player_df['stats']['std'])
#       2 std.head()
#
# File /usr/local/spark/python/pyspark/sql/session.py:894, in SparkSession.createDataFrame(self, data, schema, samplingRatio, verifySchema)
#     889 if has_pandas and isinstance(data, pandas.DataFrame):
#     890     # Create a DataFrame from pandas DataFrame.
#     891     return super(SparkSession, self).createDataFrame(  # type: ignore[call-overload]
#     892         data, schema, samplingRatio, verifySchema
#     893     )
# --> 894 return self._create_dataframe(
#     895     data, schema, samplingRatio, verifySchema  # type: ignore[arg-type]
#     896 )
#
# File /usr/local/spark/python/pyspark/sql/session.py:936, in SparkSession._create_dataframe(self, data, schema, samplingRatio, verifySchema)
#     934     rdd, struct = self._createFromRDD(data.map(prepare), schema, samplingRatio)
#     935 else:
# --> 936     rdd, struct = self._createFromLocal(map(prepare, data), schema)
#     937 assert self._jvm is not None
#     938 jrdd = self._jvm.SerDeUtil.toJavaArray(rdd._to_java_object_rdd())
#
# File /usr/local/spark/python/pyspark/sql/column.py:560, in Column.__iter__(self)
#     559 def __iter__(self) -> None:
# --> 560     raise TypeError("Column is not iterable")
#
# TypeError: Column is not iterable
